# %%
print("OK")
# Out:
# OK

# %%
import pandas as pd

# %%
df = pd.read_csv("./EasyVisa.csv")

# %%
data =df.to_dict(orient="records")

# %%
DATABASE_NAME = "US_VISA" 
COLLECTION_NAME ="visa_data"

# %%
from pymongo import MongoClient
from urllib.parse import quote_plus

username = quote_plus("haqinzmamul12")
password = quote_plus("Haqkhan@12345#")

CONNECTION_URL = (
    f"mongodb+srv://{username}:{password}"
    "@cluster0.mff61fl.mongodb.net/?retryWrites=true&w=majority"
)

# %%
client = MongoClient(CONNECTION_URL)

print("MongoDB connected successfully")
# Out:
# MongoDB connected successfully

# %%
db = client[DATABASE_NAME]
collection = db[COLLECTION_NAME]
collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('6969139d363391be791f77ca'), ObjectId('6969139d363391be791f77cb'), ObjectId('6969139d363391be791f77cc'), ObjectId('6969139d363391be791f77cd'), ObjectId('6969139d363391be791f77ce'), ObjectId('6969139d363391be791f77cf'), ObjectId('6969139d363391be791f77d0'), ObjectId('6969139d363391be791f77d1'), ObjectId('6969139d363391be791f77d2'), ObjectId('6969139d363391be791f77d3'), ObjectId('6969139d363391be791f77d4'), ObjectId('6969139d363391be791f77d5'), ObjectId('6969139d363391be791f77d6'), ObjectId('6969139d363391be791f77d7'), ObjectId('6969139d363391be791f77d8'), ObjectId('6969139d363391be791f77d9'), ObjectId('6969139d363391be791f77da'), ObjectId('6969139d363391be791f77db'), ObjectId('6969139d363391be791f77dc'), ObjectId('6969139d363391be791f77dd'), ObjectId('6969139d363391be791f77de'), ObjectId('6969139d363391be791f77df'), ObjectId('6969139d363391be791f77e0'), ObjectId('6969139d363391be791f77e1'), ObjectId('6969139d363391be791f77e2'), ObjectId('6969139d363391be791f77e3'), ObjectId('6969139d363391be791f77e4'), ObjectId('6969139d363391be791f77e5'), ObjectId('6969139d363391be791f77e6'), ObjectId('6969139d363391be791f77e7'), ObjectId('6969139d363391be791f77e8'), ObjectId('6969139d363391be791f77e9'), ObjectId('6969139d363391be791f77ea'), ObjectId('6969139d363391be791f77eb'), ObjectId('6969139d363391be791f77ec'), ObjectId('6969139d363391be791f77ed'), ObjectId('6969139d363391be791f77ee'), ObjectId('6969139d363391be791f77ef'), ObjectId('6969139d363391be791f77f0'), ObjectId('6969139d363391be791f77f1'), ObjectId('6969139d363391be791f77f2'), ObjectId('6969139d363391be791f77f3'), ObjectId('6969139d363391be791f77f4'), ObjectId('6969139d363391be791f77f5'), ObjectId('6969139d363391be791f77f6'), ObjectId('6969139d363391be791f77f7'), ObjectId('6969139d363391be791f77f8'), ObjectId('6969139d363391be791f77f9'), ObjectId('6969139d363391be791f77fa'), ObjectId('6969139d363391be791f77fb'), ObjectId('6969139d363391be791f77fc'), ObjectId('6969139d363391be791f77fd'), ObjectId('6969139d363391be791f77fe'), ObjectId('6969139d363391be791f77ff'), ObjectId('6969139d363391be791f7800'), ObjectId('6969139d363391be791f7801'), ObjectId('6969139d363391be791f7802'), ObjectId('6969139d363391be791f7803'), ObjectId('6969139d363391be791f7804'), ObjectId('6969139d363391be791f7805'), ObjectId('6969139d363391be791f7806'), ObjectId('6969139d363391be791f7807'), ObjectId('6969139d363391be791f7808'), ObjectId('6969139d363391be791f7809'), ObjectId('6969139d363391be791f780a'), ObjectId('6969139d363391be791f780b'), ObjectId('6969139d363391be791f780c'), ObjectId('6969139d363391be791f780d'), ObjectId('6969139d363391be791f780e'), ObjectId('6969139d363391be791f780f'), ObjectId('6969139d363391be791f7810'), ObjectId('6969139d363391be791f7811'), ObjectId('6969139d363391be791f7812'), ObjectId('6969139d363391be791f7813'), ObjectId('6969139d363391be791f7814'), ObjectId('6969139d363391be791f7815'), ObjectId('6969139d363391be791f7816'), ObjectId('6969139d363391be791f7817'), ObjectId('6969139d363391be791f7818'), ObjectId('6969139d363391be791f7819'), ObjectId('6969139d363391be791f781a'), ObjectId('6969139d363391be791f781b'), ObjectId('6969139d363391be791f781c'), ObjectId('6969139d363391be791f781d'), ObjectId('6969139d363391be791f781e'), ObjectId('6969139d363391be791f781f'), ObjectId('6969139d363391be791f7820'), ObjectId('6969139d363391be791f7821'), ObjectId('6969139d363391be791f7822'), ObjectId('6969139d363391be791f7823'), ObjectId('6969139d363391be791f7824'), ObjectId('6969139d363391be791f7825'), ObjectId('6969139d363391be791f7826'), ObjectId('6969139d363391be791f7827'), ObjectId('6969139d363391be791f7828'), ObjectId('6969139d363391be791f7829'), ObjectId('6969139d363391be791f782a'), ObjectId('6969139d363391be791f782b'), ObjectId('6969139d363391be791f782c'), ObjectId('6969139d363391be791f782d'), ObjectId('6969139d363391be791f782e'), ObjectId('6969139d363391be791f782f'), ObjectId('6969139d363391be791f7830'), ObjectId('6969139d363391be791f7831'), ObjectId('6969139d363391be791f ...

# %%
records = list(collection.find())

# %%
df =pd.DataFrame(records)
df.head()
# Out:
#                         _id case_id continent education_of_employee  \
# 0  6969139d363391be791f77ca  EZYV01      Asia           High School
# 1  6969139d363391be791f77cb  EZYV02      Asia              Master's
# 2  6969139d363391be791f77cc  EZYV03      Asia            Bachelor's
# 3  6969139d363391be791f77cd  EZYV04      Asia            Bachelor's
# 4  6969139d363391be791f77ce  EZYV05    Africa              Master's
#
#   has_job_experience requires_job_training  no_of_employees  yr_of_estab  \
# 0                  N                     N            14513         2007
# 1                  Y                     N             2412         2002
# 2                  N                     Y            44444         2008
# 3                  N                     N               98         1897
# 4                  Y                     N             1082         2005
#
#   region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                 West         592.2029         Hour                  Y
# 1            Northeast       83425.6500         Year                  Y
# 2                 West      122996.8600         Year                  Y
# 3                 West       83434.0300         Year                  Y
# 4                South      149907.3900         Year                  Y
#
#   case_status
# 0      Denied
# 1   Certified
# 2      Denied
# 3      Denied
# 4   Certified

# %%
if '_id' in df.columns:
    df = df.drop(columns=['_id'])

# %%
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied
# 3       83434.0300         Year                  Y      Denied
# 4      149907.3900         Year                  Y   Certified
